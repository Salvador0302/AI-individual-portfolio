# %% [markdown]
# # 01 – Exploratory Data Analysis (EDA)
#
# Exploración básica de precios y features para los 8 tickers del juego.
# Este notebook asume que ya has generado `prices.parquet` y `features.parquet`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from src.config import RAW_DATA_DIR, PROCESSED_DATA_DIR, TICKERS

# %matplotlib inline
sns.set(style='whitegrid')

# %%
# Carga de precios y features
prices_path = RAW_DATA_DIR / 'prices.parquet'
features_path = PROCESSED_DATA_DIR / 'features.parquet'

prices = pd.read_parquet(prices_path)
features = pd.read_parquet(features_path)

prices.head()

# %%
# Pasamos precios a formato largo (date, ticker, close)
if isinstance(prices.columns, pd.MultiIndex):
    prices_long = (
        prices.stack(0)",
,
,
,
